# %% [markdown]
# <a href="https://colab.research.google.com/github/hajjarshofa21/KKA-SEMESTER-1/blob/main/Fungsi_Print_Hajjar_Shofa_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Menampilkan teks sederhana

# %%
print("Saya sedang belajar Python")
# Out:
# Saya sedang belajar Python

# %% [markdown]
# 2.Menampilkan variabel

# %%
nama = "Andi"
print("Halo,nama saya" + nama)
# Out:
# Halo,nama sayaAndi

# %% [markdown]
# 3.Escape character

# %%
print("Dia berkata: \"Aku akan belajar Python\"")
print("Belajar Python itu: \nSeru \nMudah \nBermanfaat")
# Out:
# Dia berkata: "Aku akan belajar Python"
# Belajar Python itu:
# Seru
# Mudah
# Bermanfaat

# %% [markdown]
# 4.Menggunakan triple quotes

# %%
print("""Ini adalah teks multi baris.
Kita bisa menulis panjang,
tanpa harus memikirkan tanda kutip.""")
# Out:
# Ini adalah teks multi baris.
# Kita bisa menulis panjang,
# tanpa harus memikirkan tanda kutip.

# %% [markdown]
# 5.Menggunakan sep

# %%
print("A","B","C",sep="-")
# Out:
# A-B-C

# %% [markdown]
# 6.Menggunakan end

# %%
print("Hello", end=" ")  # end = spasi
print("World")
# Out:
# Hello World

# %% [markdown]
# 7.Gabungan semua materi

# %%
print("Nama",":","Andi","|","Usia",":","20 tahun",sep=" ")
print("""Hobi: Membaca,
Menulis,
Olahraga""")
# Out:
# Nama : Andi | Usia : 20 tahun
# Hobi: Membaca,
# Menulis,
# Olahraga
